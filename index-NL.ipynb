# %% [markdown]
# # Understanding Pandas Series and DataFrames - Lab
#
# ## Introduction
#
# In this lab, let's get some hands-on practice working with data cleanup using Pandas.
#
# ## Objectives
# You will be able to:
#
# - Use the `.map()` and `.apply()` methods to apply a function to a pandas Series or DataFrame
# - Perform operations to change the structure of pandas DataFrames
# - Change the index of a pandas DataFrame
# - Change data types of columns in pandas DataFrames
#
# ## Let's get started!
#
# Import the file `'turnstile_180901.txt'`.

# %%
conda install -c anaconda pep8
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: \
# The environment is inconsistent, please check the package plan carefully
# The following packages are causing the inconsistency:
#
#   - conda-forge/osx-64::jupyter_highlight_selected_word==0.2.0=py36_1000
#   - defaults/noarch::nbconvert==5.5.0=py_0
#   - conda-forge/osx-64::jupyter_nbextensions_configurator==0.4.1=py36_0
#   - conda-forge/osx-64::jupyter_latex_envs==1.4.4=py36_1000
#   - conda-forge/noarch::jupyter_contrib_core==0.3.3=py_2
#   - conda-forge/osx-64::jupyter_contrib_nbextensions==0.5.1=py36_0
#   - defaults/osx-64::nb_conda==2.2.1=py36_0
#   - defaults/osx-64::nb_conda_kernels==2.2.1=py36_0
#   - defaults/osx-64::notebook==5.7.8=py36_0
# done
#
# ## Package Plan ##
#
#   environment location: /Users/cslsh/opt/anaconda3/envs/learn-env
#
#   added / updated specs:
#     - pep8
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     bleach-3.1.0               |           py36_0         224 KB  anaconda
#     ca-certificates-2019.10.16 |                0         131 KB  anaconda
#     certifi-2019.9.11          |           py36_0         154 KB  anaconda
#     openssl-1.1.1              |       h1de35cc_0         4.6 MB  anaconda
#     pep8-1.7.1                 |           py36_0          51 KB  anaconda
#     ------------------------------------------------------------
#                                            Total:         5.2 MB
#
# The following NEW packages will be INSTALLED:
#
#   bleach             anaconda/osx-64::bleach-3.1.0-py36_0
#   pep8               anaconda/osx-64::pep8-1.7.1-py36_0
#
# The following packages will be UPDATED:
#
#   ca-certificates    pkgs/main::ca-certificates-2019.8.28-0 --> anaconda::ca-certificates-2019.10.16-0
#   openssl              pkgs/main::openssl-1.1.1d-h1de35cc_3 --> anaconda::openssl-1.1.1-h1de35cc_0
#
# The following packages will be SUPERSEDED by a higher-priority channel:
#
#   certifi                                         pkgs/main --> anaconda
#
#
#
# Downloading and Extracting Packages
# certifi-2019.9.11    | 154 KB    | ##################################### | 100%
# openssl-1.1.1        | 4.6 MB    | ##################################### | 100%
# ca-certificates-2019 | 131 KB    | ##################################### | 100%
# pep8-1.7.1           | 51 KB     | ##################################### | 100%
# bleach-3.1.0         | 224 KB    | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
#
# Note: you may need to restart the kernel to use updated packages.

# %%
# Import the required libraries
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# Import the file 'turnstile_180901.txt'
df = pd.read_csv('turnstile_180901.txt')

# Print the number of rows ans columns in df
print(df.shape)

# Print the first five rows of df
df.head(5)
# Out:
# (197625, 11)
#     C/A  UNIT       SCP STATION LINENAME DIVISION        DATE      TIME  \
# 0  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  00:00:00
# 1  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  04:00:00
# 2  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  08:00:00
# 3  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  12:00:00
# 4  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  16:00:00
#
#       DESC  ENTRIES  \
# 0  REGULAR  6736067
# 1  REGULAR  6736087
# 2  REGULAR  6736105
# 3  REGULAR  6736180
# 4  REGULAR  6736349
#
#    EXITS
# 0                                            2283184
# 1                                            2283188
# 2                                            2283229
# 3                                            2283314
# 4                                            2283384

# %% [markdown]
# Rename all the columns to lower case:

# %%
df.columns
# Out:
# Index(['C/A', 'UNIT', 'SCP', 'STATION', 'LINENAME', 'DIVISION', 'DATE', 'TIME',
#        'DESC', 'ENTRIES',
#        'EXITS                                                               '],
#       dtype='object')

# %%
# Rename all the columns to lower case
#uci.columns = ["uci_" + x.lower().replace(" ", "_") for x in uci.columns] #replace space with _ and add uci_
df.columns = [x.lower() for x in df.columns]
df.columns
# Out:
# Index(['c/a', 'unit', 'scp', 'station', 'linename', 'division', 'date', 'time',
#        'desc', 'entries',
#        'exits                                                               '],
#       dtype='object')

# %% [markdown]
# Change the index to `'linename'`:

# %%
type(df.index)
# Out:
# pandas.core.indexes.range.RangeIndex

# %%
df.reset_index()

# %%
# Change the index to 'linename'
df['index'] = df['linename']
df.head(5)
# Out:
#     c/a  unit       scp station linename division        date      time  \
# 0  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  00:00:00
# 1  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  04:00:00
# 2  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  08:00:00
# 3  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  12:00:00
# 4  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  16:00:00
#
#       desc  entries  \
# 0  REGULAR  6736067
# 1  REGULAR  6736087
# 2  REGULAR  6736105
# 3  REGULAR  6736180
# 4  REGULAR  6736349
#
#    exits                                                                 \
# 0                                            2283184
# 1                                            2283188
# 2                                            2283229
# 3                                            2283314
# 4                                            2283384
#
#      index
# 0  NQR456W
# 1  NQR456W
# 2  NQR456W
# 3  NQR456W
# 4  NQR456W

# %% [markdown]
# Reset the index:

# %%
# Reset the index
df.reset_index()
#df['linename'] = df['index']
df.head(5)
# Out:
#     c/a  unit       scp station linename division        date      time  \
# 0  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  00:00:00
# 1  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  04:00:00
# 2  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  08:00:00
# 3  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  12:00:00
# 4  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  16:00:00
#
#       desc  entries  \
# 0  REGULAR  6736067
# 1  REGULAR  6736087
# 2  REGULAR  6736105
# 3  REGULAR  6736180
# 4  REGULAR  6736349
#
#    exits                                                                 \
# 0                                            2283184
# 1                                            2283188
# 2                                            2283229
# 3                                            2283314
# 4                                            2283384
#
#      index
# 0  NQR456W
# 1  NQR456W
# 2  NQR456W
# 3  NQR456W
# 4  NQR456W

# %% [markdown]
# Create another column `'Num_Lines'` that is a count of how many lines pass through a station. Then sort your DataFrame by this column in descending order.
#
# *Hint: According to the [data dictionary](http://web.mta.info/developers/resources/nyct/turnstile/ts_Field_Description.txt), LINENAME represents all train lines that can be boarded at a given station. Normally lines are represented by one character. For example, LINENAME 456NQR represents trains 4, 5, 6, N, Q, and R.*

# %%
len(df.linename[0])
# Out:
# 7

# %%
def lengIn(x):
    return len(x)

# %%
# Add a new 'num_lines' column
df["num_lines"] = df.linename.map(lengIn)

# %%
df
# Out:
#           c/a  unit       scp        station linename division        date  \
# 0        A002  R051  02-00-00          59 ST  NQR456W      BMT  08/25/2018
# 1        A002  R051  02-00-00          59 ST  NQR456W      BMT  08/25/2018
# 2        A002  R051  02-00-00          59 ST  NQR456W      BMT  08/25/2018
# 3        A002  R051  02-00-00          59 ST  NQR456W      BMT  08/25/2018
# 4        A002  R051  02-00-00          59 ST  NQR456W      BMT  08/25/2018
# ...       ...   ...       ...            ...      ...      ...         ...
# 197620  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  08/31/2018
# 197621  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  08/31/2018
# 197622  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  08/31/2018
# 197623  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  08/31/2018
# 197624  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  08/31/2018
#
#             time     desc  entries  \
# 0       00:00:00  REGULAR  6736067
# 1       04:00:00  REGULAR  6736087
# 2       08:00:00  REGULAR  6736105
# 3       12:00:00  REGULAR  6736180
# 4       16:00:00  REGULAR  6736349
# ...          ...      ...      ...
# 197620  05:00:00  REGULAR     5554
# 197621  09:00:00  REGULAR     5554
# 197622  13:00:00  REGULAR     5554
# 197623  17:00:00  REGULAR     5554
# 197624  21:00:00  REGULAR     5554
#
#         exits                                                                 \
# 0                                                 2283184
# 1                                                 2283188
# 2                                                 2283229
# 3                                                 2283314
# 4                                                 2283384
# ...                                                   ...
# 197620                                                348
# 197621                                                348
# 197622                                                348
# 197623                                                348
# 197624                                                348
#
#         num_lines
# 0               7
# 1               7
# 2               7
# 3               7
# 4               7
# ...           ...
# 197620          1
# 197621          1
# 197622          1
# 197623          1
# 197624          1
#
# [197625 rows x 12 columns]

# %% [markdown]
# Write a function to clean column names:

# %%
type(df.columns[0])
# Out:
# str

# %%
def clean(col_name):
    # Clean the column name in any way you want to. Hint: think back to str methods 
    cleaned = "df_" + col_name
    return cleaned

# %%
clean("AFD")
# Out:
# 'df_AFD'

# %%
# Use the above function to clean the column names
df.columns = df.columns.map(clean)

# %%
# Check to ensure the column names were cleaned
df.columns
# Out:
# Index(['df_c/a', 'df_unit', 'df_scp', 'df_station', 'df_linename',
#        'df_division', 'df_date', 'df_time', 'df_desc', 'df_entries',
#        'df_exits                                                               ',
#        'df_num_lines'],
#       dtype='object')

# %% [markdown]
# - Change the data type of the `'date'` column to a date
# - Add a new column `'day_of_week'` that represents the day of the week

# %%
# Convert the data type of the 'date' column to a date
import datetime
df["df_date"] = pd.to_datetime(df["df_date"])
df["df_date"].head()
# Add a new column 'day_of_week' that represents the day of the week 
df["day_of_week"] = df["df_date"].dt.day_name()

# %%
df.head()
# Out:
#   df_c/a df_unit    df_scp df_station df_linename df_division    df_date  \
# 0   A002    R051  02-00-00      59 ST     NQR456W         BMT 2018-08-25
# 1   A002    R051  02-00-00      59 ST     NQR456W         BMT 2018-08-25
# 2   A002    R051  02-00-00      59 ST     NQR456W         BMT 2018-08-25
# 3   A002    R051  02-00-00      59 ST     NQR456W         BMT 2018-08-25
# 4   A002    R051  02-00-00      59 ST     NQR456W         BMT 2018-08-25
#
#     df_time  df_desc  df_entries  \
# 0  00:00:00  REGULAR     6736067
# 1  04:00:00  REGULAR     6736087
# 2  08:00:00  REGULAR     6736105
# 3  12:00:00  REGULAR     6736180
# 4  16:00:00  REGULAR     6736349
#
#    df_exits                                                                 \
# 0                                            2283184
# 1                                            2283188
# 2                                            2283229
# 3                                            2283314
# 4                                            2283384
#
#    df_num_lines day_of_week
# 0             7    Saturday
# 1             7    Saturday
# 2             7    Saturday
# 3             7    Saturday
# 4             7    Saturday

# %%
# Group the data by day of week and plot the sum of the numeric columns
grouped = df.groupby('day_of_week').sum()
grouped.plot(kind='barh')
plt.show()

# %% [markdown]
# - Remove the index of `grouped`
# - Print the first five rows of `grouped`

# %%
grouped
# Out:
#                 df_entries  \
# day_of_week
# Friday       1110224700078
# Monday       1114237052454
# Saturday     1115661545514
# Sunday       1192306179082
# Thursday     1122723988662
# Tuesday      1143313287046
# Wednesday    1123655222441
#
#              df_exits                                                                 \
# day_of_week
# Friday                                            906799065337
# Monday                                            911938153513
# Saturday                                          909142081474
# Sunday                                            959223750461
# Thursday                                          920691927110
# Tuesday                                           942230721477
# Wednesday                                         920630864687
#
#              df_num_lines
# day_of_week
# Friday              75573
# Monday              76110
# Saturday            74725
# Sunday              75306
# Thursday            76607
# Tuesday             77303
# Wednesday           75713

# %%
grouped.reset_index(drop=True)
# Out:
#       df_entries  \
# 0  1110224700078
# 1  1114237052454
# 2  1115661545514
# 3  1192306179082
# 4  1122723988662
# 5  1143313287046
# 6  1123655222441
#
#    df_exits                                                                 \
# 0                                       906799065337
# 1                                       911938153513
# 2                                       909142081474
# 3                                       959223750461
# 4                                       920691927110
# 5                                       942230721477
# 6                                       920630864687
#
#    df_num_lines
# 0         75573
# 1         76110
# 2         74725
# 3         75306
# 4         76607
# 5         77303
# 6         75713

# %%
grouped.reset_index(inplace=True)
grouped.reset_index(inplace=True)

# %%
grouped.head(5)
# Out:
#    index day_of_week     df_entries  \
# 0      0      Friday  1110224700078
# 1      1      Monday  1114237052454
# 2      2    Saturday  1115661545514
# 3      3      Sunday  1192306179082
# 4      4    Thursday  1122723988662
#
#    df_exits                                                                 \
# 0                                       906799065337
# 1                                       911938153513
# 2                                       909142081474
# 3                                       959223750461
# 4                                       920691927110
#
#    df_num_lines
# 0         75573
# 1         76110
# 2         74725
# 3         75306
# 4         76607

# %%
# Reset the index of grouped
#grouped = None
grouped = grouped.drop("day_of_week", axis = 1)
grouped = grouped.rename(columns={'index' : 'day_of_week'})
# Print the first five rows of grouped
grouped.head(5)
# Out:
#    day_of_week     df_entries  \
# 0            0  1110224700078
# 1            1  1114237052454
# 2            2  1115661545514
# 3            3  1192306179082
# 4            4  1122723988662
#
#    df_exits                                                                 \
# 0                                       906799065337
# 1                                       911938153513
# 2                                       909142081474
# 3                                       959223750461
# 4                                       920691927110
#
#    df_num_lines
# 0         75573
# 1         76110
# 2         74725
# 3         75306
# 4         76607

# %% [markdown]
# Add a new column `'is_weekend'` that maps the `'day_of_week'` column using the dictionary `weekend_map`

# %%
# Use this dictionary to create a new column 
weekend_map = {0:False, 1:False, 2:False, 3:False, 4:False, 5:True, 6:True}

# Add a new column 'is_weekend' that maps the 'day_of_week' column using weekend_map
grouped['is_weekend'] = grouped['day_of_week'].map(weekend_map)

# %%
grouped
# Out:
#    day_of_week     df_entries  \
# 0            0  1110224700078
# 1            1  1114237052454
# 2            2  1115661545514
# 3            3  1192306179082
# 4            4  1122723988662
# 5            5  1143313287046
# 6            6  1123655222441
#
#    df_exits                                                                 \
# 0                                       906799065337
# 1                                       911938153513
# 2                                       909142081474
# 3                                       959223750461
# 4                                       920691927110
# 5                                       942230721477
# 6                                       920630864687
#
#    df_num_lines  is_weekend
# 0         75573       False
# 1         76110       False
# 2         74725       False
# 3         75306       False
# 4         76607       False
# 5         77303        True
# 6         75713        True

# %%
# Group the data by weekend/weekday and plot the sum of the numeric columns
wkend = grouped.groupby('is_weekend').mean()
wkend[['df_entries', 'df_exits']].plot(kind='barh')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-118-979b9d47355d> in <module>
#       1 # Group the data by weekend/weekday and plot the sum of the numeric columns
#       2 wkend = grouped.groupby('is_weekend').mean()
# ----> 3 wkend[['df_entries', 'df_exits']].plot(kind='barh')
#       4 plt.show()
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2984             if is_iterator(key):
#    2985                 key = list(key)
# -> 2986             indexer = self.loc._convert_to_indexer(key, axis=1, raise_missing=True)
#    2987
#    2988         # take() does not accept boolean indexers
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/pandas/core/indexing.py in _convert_to_indexer(self, obj, axis, is_setter, raise_missing)
#    1283                 # When setting, missing keys are not allowed, even with .loc:
#    1284                 kwargs = {"raise_missing": True if is_setter else raise_missing}
# -> 1285                 return self._get_listlike_indexer(obj, axis, **kwargs)[1]
#    1286         else:
#    1287             try:
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/pandas/core/indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1090
#    1091         self._validate_read_indexer(
# -> 1092             keyarr, indexer, o._get_axis_number(axis), raise_missing=raise_missing
#    1093         )
#    1094         return keyarr, indexer
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/pandas/core/indexing.py in _validate_read_indexer(self, key, indexer, axis, raise_missing)
#    1183             if not (self.name == "loc" and not raise_missing):
#    1184                 not_found = list(set(key) - set(ax))
# -> 1185                 raise KeyError("{} not in index".format(not_found))
#    1186
#    1187             # we skip the warning on Categorical/Interval
#
# KeyError: "['df_exits'] not in index"

# %% [markdown]
# Remove the `'c/a'` and `'scp'` columns.

# %%
# Remove the 'c/a' and 'scp' columns
df = None
df.head(2)

# %% [markdown]
# ## Analysis Question
#
# What is misleading about the day of week and weekend/weekday charts you just plotted?

# %%
# Your answer here

# %% [markdown]
# ## Summary
#
# Great! You practiced your data cleanup skills using Pandas.
